# %% [markdown]
# # Simple Linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df['Total_spend'] = df['TV']+df['radio']+df['newspaper']

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  Total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
plt.figure(figsize = (10,4), dpi = 200)
sns.scatterplot(data = df, x='Total_spend', y = 'sales')
# Out:
# <AxesSubplot:xlabel='Total_spend', ylabel='sales'>

# %%
# Seaborn for regression line

sns.regplot(data = df, y = 'sales', x = 'Total_spend')
# Out:
# <AxesSubplot:xlabel='Total_spend', ylabel='sales'>

# %%
X = df['Total_spend']
y = df['sales']

# %%
np.polyfit(X, y, deg = 1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend  = np.linspace(0, 500, 100)

# %%
# y = B1x + B0
predicted_sales = 0.04868788*potential_spend + 4.24302822

# %%
sns.scatterplot(x = 'Total_spend', y = 'sales', data = df)
plt.plot(potential_spend, predicted_sales, color = 'red')

# %%
spend = 200
predicted_sales = 0.04868788*spend + 4.24302822

# %%
predicted_sales
# Out:
# 13.98060422

# %%
np.polyfit(X,y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
# y = B1x + B0
# y = B3x**3+B2x**2+B1x+B0

# %%
pot_spend = np.linspace(0,500,100)

# %%
pred_salse = 3.07615033e-07 *pot_spend**3 +-1.89392449e-04*pot_spend**2+8.20886302e-02*pot_spend+2.70495053e+00

# %%
sns.scatterplot(x = 'Total_spend', y = 'sales', data = df)
plt.plot(potential_spend, pred_salse, color = 'red')
